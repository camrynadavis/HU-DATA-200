# %% [markdown]
# ## Research Question

# %% [markdown]
# How can location and public school funding contribute to the underrepresentation of Black and Hispanic youth in high-cost sports by limiting access to facilities, specialized sports training, injury management and scouting opportunities?

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Sports specialization involves year-round training and competition, and requires costly investments towards participation, travel, and equipment fees, which creates significant finanicial barriers for youth from lower socioeconomic backgrounds. Aside from this, public school funding disparities can limit access to appropriate facilities, personnel, or physical education, which could further hinder sports participation opportunities for youth in lower SES communities. These disparities can contribute to underrepresentation of Black or Hispanic youth in sports with high financial barriers -- hockey, gymnastics, tennis, etc., while sports such as track and field are less expensive, and therefore more accessible.

# %% [markdown]
# ### Potential Subtopics

# %% [markdown]
# - Correlation between public school funding and facility quality
# - How racial identities or stereotypes can affect an athlete's sense of belonging in a specific sport
# - Connection between SES and knowledge of sports injury education (ex. concussion education, safety protocols, etc.)

# %% [markdown]
# ## Data Definition

# %% [markdown]
# <b>Public School Characteristics 2022-23</b>
#
# Last Updated: October 21, 2024
#
# https://catalog.data.gov/dataset/public-school-characteristics-2022-23-451db
#
# The National Center for Education Statistics (NCES) gathers demographic and geographic data about U.S public schools and factors such as enrollment and Title I status. Further information consists of the percentage of students with free or reduced lunch eligibility. By researching both this dataset and the YRBSS, researchers could analyze patterns between students or schools with a lower SES and the rates of physical activity rates.

# %% [markdown]
# ### Additional Datasets of Interest

# %% [markdown]
# <b>Nutrition, Physical Activity, and Obesity - Youth Risk Behavior Surveillance System</b>
#
# Last Updated: February 4, 2025
#
# https://catalog.data.gov/dataset/nutrition-physical-activity-and-obesity-youth-risk-behavior-surveillance-system
#
# Conducted by the Centers for Disease Control and Prevention (CDC), the Youth Risk Behavior Surveillance System (YRBSS) monitors health behaviors in middle and high school students nationwide. It collects data regarding physical activity and nutrition, along with geographic and socioeconomic factors. By collecting this data, it could be used to further research on the impact socioeconomic factors have on health behaviors.

# %% [markdown]
# ## Data Collection

# %%
import numpy as np                
import pandas as pd              
import matplotlib.pyplot as plt   
import seaborn as sns               

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read the Data

# %%
path = pd.read_csv('Public_School_Characteristics_2022-23.csv')
psChar_23 = pd.DataFrame(path)

# %%
psChar_23.head(7)
# Out:
#            X         Y  OBJECTID      NCESSCH   SURVYEAR STABR   LEAID  \
# 0 -86.206200  34.26020         1  10000500870  2022-2023    AL  100005
# 1 -86.204900  34.26220         2  10000500871  2022-2023    AL  100005
# 2 -86.220100  34.27330         3  10000500879  2022-2023    AL  100005
# 3 -86.221806  34.25270         4  10000500889  2022-2023    AL  100005
# 4 -86.193300  34.28980         5  10000501616  2022-2023    AL  100005
# 5 -86.221800  34.25330         6  10000502150  2022-2023    AL  100005
# 6 -86.254153  34.53375         7  10000600193  2022-2023    AL  100006
#
#   ST_LEAID          LEA_NAME                           SCH_NAME  \
# 0   AL-101  Albertville City          Albertville Middle School
# 1   AL-101  Albertville City            Albertville High School
# 2   AL-101  Albertville City    Albertville Intermediate School
# 3   AL-101  Albertville City      Albertville Elementary School
# 4   AL-101  Albertville City  Albertville Kindergarten and PreK
# 5   AL-101  Albertville City         Albertville Primary School
# 6   AL-048   Marshall County       Kate Duncan Smith DAR Middle
#
#               LSTREET1 LSTREET2        LCITY LSTATE   LZIP LZIP4  \
# 0    600 E Alabama Ave      NaN  Albertville     AL  35950
# 1     402 E McCord Ave      NaN  Albertville     AL  35950  2322
# 2   901 W McKinney Ave      NaN  Albertville     AL  35950  1300
# 3   145 West End Drive      NaN  Albertville     AL  35950
# 4  257 Country Club Rd      NaN  Albertville     AL  35951  3927
# 5       1100 Horton Rd      NaN  Albertville     AL  35950  2532
# 6         6077 Main St      NaN        Grant     AL  35747
#
#            PHONE CHARTER_TEXT      VIRTUAL GSLO GSHI SCHOOL_LEVEL  STATUS  \
# 0  (256)878-2341           No  Not Virtual   07   08       Middle       1
# 1  (256)894-5000           No  Not Virtual   09   12         High       1
# 2  (256)878-7698           No  Not Virtual   05   06       Middle       1
# 3  (256)894-4822           No  Not Virtual   03   04   Elementary       1
# 4  (256)878-7922           No  Not Virtual   PK   KG   Elementary       1
# 5  (256)878-6611           No  Not Virtual   01   02   Elementary       1
# 6  (256)728-5950           No  Not Virtual   05   08       Middle       1
#
#   SCHOOL_TYPE_TEXT          SY_STATUS_TEXT            ULOCALE  \
# 0   Regular School  Currently operational    32-Town: Distant
# 1   Regular School  Currently operational    32-Town: Distant
# 2   Regular School  Currently operational    32-Town: Distant
# 3   Regular School  Currently operational    32-Town: Distant
# 4   Regular School  Currently operational    32-Town: Distant
# 5   Regular School  Currently operational    32-Town: Distant
# 6   Regular School  Currently operational   42-Rural: Distant
#
#             NMCNTY  TOTFRL  FRELCH  REDLCH  DIRECTCERT     PK     KG    G01  \
# 0  Marshall County     697     654      43         587    NaN    NaN    NaN
# 1  Marshall County    1254    1178      76        1059    NaN    NaN    NaN
# 2  Marshall County     718     665      53         570    NaN    NaN    NaN
# 3  Marshall County     723     680      43         583    NaN    NaN    NaN
# 4  Marshall County     392     367      25         240  133.0  473.0    NaN
# 5  Marshall County     779     726      53         617    0.0    NaN  427.0
# 6  Marshall County     151     123      28         194    NaN    NaN    NaN
#
#      G02    G03    G04    G05    G06    G07    G08    G09    G10    G11  \
# 0    NaN    NaN    NaN    NaN    NaN  440.0  450.0    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN    NaN    NaN  493.0  442.0  390.0
# 2    NaN    NaN    NaN  412.0  462.0    NaN    NaN    NaN    NaN    NaN
# 3    NaN  430.0  444.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5  517.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6    NaN    NaN    NaN   95.0   97.0   86.0   86.0    NaN    NaN    NaN
#
#      G12  G13  UG  AE  TOTMENROL  TOTFENROL   TOTAL  MEMBER        FTE  \
# 0    NaN  NaN NaN NaN      459.0      431.0   890.0   890.0  45.000000
# 1  387.0  NaN NaN NaN      868.0      844.0  1712.0  1712.0  85.199997
# 2    NaN  NaN NaN NaN      451.0      423.0   874.0   874.0  43.000000
# 3    NaN  NaN NaN NaN      463.0      411.0   874.0   874.0  43.000000
# 4    NaN  NaN NaN NaN      304.0      302.0   606.0   606.0  26.000000
# 5    NaN  NaN NaN NaN      498.0      446.0   944.0   944.0  61.000000
# 101384                  JULIUS E SPRAUVE         14 18 ESTATE ENIGHED
# 101385        LOCKHART ELEMENTARY SCHOOL             41 ESTATE THOMAS
# 101386   ULLA F MULLER ELEMENTARY SCHOOL            7B ESTATE CONTANT
# 101387   YVONNE BOWSKY ELEMENTARY SCHOOL    15B and 16 ESTATE MANDAHL
# 101388        CANCRYN JUNIOR HIGH SCHOOL                  1 CROWN BAY
# 101389      BERTHA BOSCHULTE JUNIOR HIGH           9 1 and 12A BOVONI
#
#        LSTREET2         LCITY LSTATE  LZIP LZIP4          PHONE CHARTER_TEXT  \
# 101383      NaN  Saint Thomas     VI   802        (340)774-7001            N
# 101384      NaN    Saint John     VI   831        (340)776-6336            N
# 101385      NaN  Saint Thomas     VI   802        (340)775-0820            N
# 101386      NaN  Saint Thomas     VI   802        (340)774-0059            N
# 101387      NaN  Saint Thomas     VI   802        (340)775-3220            N
# 101388      NaN  Saint Thomas     VI   804        (340)774-4540            N
# 101389      NaN  Saint Thomas     VI   802        (340)775-4222            N
#
#             VIRTUAL GSLO GSHI SCHOOL_LEVEL  STATUS SCHOOL_TYPE_TEXT  \
# 101383  Not Virtual   PK   06   Elementary       1   Regular School
# 101384  Not Virtual   PK   08   Elementary       1   Regular School
# 101385  Not Virtual   KG   03   Elementary       1   Regular School
# 101386  Not Virtual   KG   06   Elementary       1   Regular School
# 101387  Not Virtual   PK   05   Elementary       1   Regular School
# 101388  Not Virtual   04   08       Middle       1   Regular School
# 101389  Not Virtual   06   08       Middle       1   Regular School
#
#                 SY_STATUS_TEXT          ULOCALE             NMCNTY  TOTFRL  \
# 101383  Currently operational   33-Town: Remote  St. Thomas Island     228
# 101384  Currently operational   33-Town: Remote    St. John Island     199
# 101385  Currently operational   33-Town: Remote  St. Thomas Island     295
# 101386  Currently operational   33-Town: Remote  St. Thomas Island     417
# 101387  Currently operational   33-Town: Remote  St. Thomas Island     425
# 101388  Currently operational   33-Town: Remote  St. Thomas Island     683
# 101389  Currently operational   33-Town: Remote  St. Thomas Island     504
#
#         FRELCH  REDLCH  DIRECTCERT    PK    KG   G01   G02   G03   G04    G05  \
# 101383     228       0          -1  19.0  25.0  25.0  25.0  31.0  34.0   34.0
# 101384     199       0          -1   8.0  21.0  16.0  21.0  14.0  24.0   20.0
# 101385     295       0          -1   NaN  77.0  75.0  69.0  77.0   NaN    NaN
# 101386     417       0          -1   NaN  52.0  53.0  51.0  47.0  70.0   79.0
# 101387     425       0          -1  22.0  62.0  67.0  66.0  75.0  68.0   68.0
# 101388     683       0          -1   NaN   NaN   NaN   NaN   NaN  77.0  119.0
# 101389     504       0          -1   NaN   NaN   NaN   NaN   NaN   NaN    NaN
#
#           G06    G07    G08  G09  G10  G11  G12  G13  UG  AE  TOTMENROL  \
# 101383   38.0    NaN    NaN  NaN  NaN  NaN  NaN  NaN NaN NaN      121.0
# 101384   26.0   27.0   25.0  NaN  NaN  NaN  NaN  NaN NaN NaN      103.0
# 101385    NaN    NaN    NaN  NaN  NaN  NaN  NaN  NaN NaN NaN      171.0
# 101386   68.0    NaN    NaN  NaN  NaN  NaN  NaN  NaN NaN NaN      200.0
# 101387    NaN    NaN    NaN  NaN  NaN  NaN  NaN  NaN NaN NaN      252.0
# 101388   96.0  189.0  205.0  NaN  NaN  NaN  NaN  NaN NaN NaN      361.0
# 101389  145.0  169.0  193.0  NaN  NaN  NaN  NaN  NaN NaN NaN      279.0
#
#         TOTFENROL  TOTAL  MEMBER   FTE  STUTERATIO  AMALM  AMALF   AM  ASALM  \
# 101383      110.0  231.0   231.0  16.0       14.44    0.0    0.0  0.0    2.0
# 101384       99.0  202.0   202.0  20.0       10.10    1.0    0.0  1.0    0.0
# 101385      127.0  298.0   298.0  18.0       16.56    0.0    0.0  0.0    4.0
# 101386      220.0  420.0   420.0  28.0       15.00    0.0    2.0  2.0    2.0
# 101387      176.0  428.0   428.0  34.0       12.59    1.0    1.0  2.0    5.0
# 101388      325.0  686.0   686.0  62.0       11.06    0.0    0.0  0.0    2.0
# 101389      228.0  507.0   507.0  49.0       10.35    0.0    0.0  0.0    2.0
#
#         ASALF   AS  BLALM  BLALF     BL  HPALM  HPALF   HP  HIALM  HIALF  \
# 101383    2.0  4.0   99.0   93.0  192.0    0.0    0.0  0.0    8.0    5.0
# 101384    0.0  0.0   79.0   68.0  147.0    0.0    0.0  0.0   22.0   29.0
# 101385    3.0  7.0  132.0   92.0  224.0    0.0    0.0  0.0   33.0   30.0
# 101386    4.0  6.0  167.0  182.0  349.0    0.0    0.0  0.0   27.0   27.0
# 101387    4.0  9.0  201.0  144.0  345.0    0.0    0.0  0.0   37.0   22.0
# 101388    2.0  4.0  279.0  250.0  529.0    0.0    0.0  0.0   74.0   62.0
# 101389    1.0  3.0  250.0  204.0  454.0    0.0    0.0  0.0   27.0   21.0
#
#            HI  TRALM  TRALF   TR  WHALM  WHALF    WH     LATCOD     LONCOD
# 101383   13.0    2.0    1.0  3.0   10.0    9.0  19.0  18.352146 -64.932456
# 101384   51.0    0.0    0.0  0.0    1.0    2.0   3.0  18.330464 -64.793916
# 101385   63.0    1.0    2.0  3.0    1.0    0.0   1.0  18.341950 -64.917602
# 101386   54.0    2.0    0.0  2.0    2.0    5.0   7.0  18.338742 -64.952483
# 101387   59.0    0.0    1.0  1.0    8.0    4.0  12.0  18.354782 -64.899024
# 101388  136.0    0.0    1.0  1.0    6.0   10.0  16.0  18.336658 -64.945940
# 101389   48.0    0.0    0.0  0.0    0.0    2.0   2.0  18.318230 -64.890311

# %%
psChar_23.shape
# Out:
# (101390, 77)

# %% [markdown]
# - The dataframe has 101,390 rows of data.
# - The dataframe has 68 columns or features.
# - There are 6,894,520 total datapoints observed in the dataset.

# %%
psChar_23.info(show_counts=True, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101390 entries, 0 to 101389
# Data columns (total 77 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   X                 101390 non-null  float64
#  1   Y                 101390 non-null  float64
#  2   OBJECTID          101390 non-null  int64
#  3   NCESSCH           101390 non-null  int64
#  4   SURVYEAR          101390 non-null  object
#  5   STABR             101390 non-null  object
#  6   LEAID             101390 non-null  int64
#  7   ST_LEAID          101390 non-null  object
#  8   LEA_NAME          101390 non-null  object
#  9   SCH_NAME          101390 non-null  object
#  10  LSTREET1          101389 non-null  object
#  11  LSTREET2          572 non-null     object
#  12  LCITY             101390 non-null  object
#  13  LSTATE            101390 non-null  object
#  14  LZIP              101390 non-null  int64
#  15  LZIP4             101390 non-null  object
#  16  PHONE             101390 non-null  object
#  17  CHARTER_TEXT      101390 non-null  object
#  18  VIRTUAL           101390 non-null  object
#  19  GSLO              101390 non-null  object
#  20  GSHI              101390 non-null  object
#  21  SCHOOL_LEVEL      101390 non-null  object
#  22  STATUS            101390 non-null  int64
#  23  SCHOOL_TYPE_TEXT  101390 non-null  object
#  24  SY_STATUS_TEXT    101390 non-null  object
#  25  ULOCALE           101390 non-null  object
#  26  NMCNTY            101390 non-null  object
#  27  TOTFRL            101390 non-null  int64
#  28  FRELCH            101390 non-null  int64
#  29  REDLCH            101390 non-null  int64
#  30  DIRECTCERT        101390 non-null  int64
#  31  PK                32392 non-null   float64
#  32  KG                54061 non-null   float64
#  33  G01               54412 non-null   float64
#  34  G02               54469 non-null   float64
#  35  G03               54459 non-null   float64
#  36  G04               54258 non-null   float64
#  37  G05               53014 non-null   float64
#  38  G06               38023 non-null   float64
#  39  G07               33224 non-null   float64
#  40  G08               33492 non-null   float64
#  41  G09               28101 non-null   float64
#  42  G10               27889 non-null   float64
#  43  G11               27888 non-null   float64
#  44  G12               27816 non-null   float64
#  45  G13               133 non-null     float64
#  46  UG                7889 non-null    float64
#  47  AE                183 non-null     float64
#  48  TOTMENROL         98910 non-null   float64
#  49  TOTFENROL         98910 non-null   float64
#  50  TOTAL             99719 non-null   float64
#  51  MEMBER            99719 non-null   float64
#  52  FTE               97537 non-null   float64
#  53  STUTERATIO        99576 non-null   float64
#  54  AMALM             98809 non-null   float64
#  55  AMALF             98811 non-null   float64
#  56  AM                98857 non-null   float64
#  57  ASALM             98898 non-null   float64
#  58  ASALF             98900 non-null   float64
#  59  AS                98906 non-null   float64
#  60  BLALM             98896 non-null   float64
#  61  BLALF             98893 non-null   float64
#  62  BL                98903 non-null   float64
#  63  HPALM             98782 non-null   float64
#  64  HPALF             98783 non-null   float64
#  65  HP                98829 non-null   float64
#  66  HIALM             98909 non-null   float64
#  67  HIALF             98910 non-null   float64
#  68  HI                98910 non-null   float64
#  69  TRALM             98903 non-null   float64
#  70  TRALF             98905 non-null   float64
#  71  TR                98906 non-null   float64
#  72  WHALM             98909 non-null   float64
#  73  WHALF             98909 non-null   float64
#  74  WH                98910 non-null   float64
#  75  LATCOD            101390 non-null  float64
#  76  LONCOD            101390 non-null  float64
# dtypes: float64(48), int64(9), object(20)
# memory usage: 59.6+ MB

# %%
ps23Cols = psChar_23.columns
ps23Cols
# Out:
# Index(['X', 'Y', 'OBJECTID', 'NCESSCH', 'SURVYEAR', 'STABR', 'LEAID',
#        'ST_LEAID', 'LEA_NAME', 'SCH_NAME', 'LSTREET1', 'LSTREET2', 'LCITY',
#        'LSTATE', 'LZIP', 'LZIP4', 'PHONE', 'CHARTER_TEXT', 'VIRTUAL', 'GSLO',
#        'GSHI', 'SCHOOL_LEVEL', 'STATUS', 'SCHOOL_TYPE_TEXT', 'SY_STATUS_TEXT',
#        'ULOCALE', 'NMCNTY', 'TOTFRL', 'FRELCH', 'REDLCH', 'DIRECTCERT', 'PK',
#        'KG', 'G01', 'G02', 'G03', 'G04', 'G05', 'G06', 'G07', 'G08', 'G09',
#        'G10', 'G11', 'G12', 'G13', 'UG', 'AE', 'TOTMENROL', 'TOTFENROL',
#        'TOTAL', 'MEMBER', 'FTE', 'STUTERATIO', 'AMALM', 'AMALF', 'AM', 'ASALM',
#        'ASALF', 'AS', 'BLALM', 'BLALF', 'BL', 'HPALM', 'HPALF', 'HP', 'HIALM',
#        'HIALF', 'HI', 'TRALM', 'TRALF', 'TR', 'WHALM', 'WHALF', 'WH', 'LATCOD',
#        'LONCOD'],
#       dtype='object')

# %%
psChar_23 = psChar_23.rename(columns = {'OBJECTID':'ObjectID','NCESSCH':'NCESID','SURVYEAR':'SurveyYear', 
                                        'STABR':'StateABR','LEA_NAME':'LEAname','SCH_NAME':'SchoolName', 
                                        'LSTREET1':'Street1','LSTREET2':'Street2','LCITY':'City',
                                        'LSTATE':'State','LZIP':'Zip','LZIP4':'Zip4', 
                                        'PHONE':'Phone', 'CHARTER_TEXT':'Charter', 'VIRTUAL':'Virtual', 
                                        'GSLO':'LowestGrade','GSHI':'HighestGrade', 
                                        'SCHOOL_LEVEL':'SchoolLevel', 
                                        'STATUS':'Status', 'SCHOOL_TYPE_TEXT':'SchoolType', 
                                        'SY_STATUS_TEXT':'Status_Text',
                                        'ULOCALE':'Locale', 'NMCNTY':'County', 
                                        'TOTFRL':'TotalFreeLunch', 
                                        'FRELCH':'FreeLunch', 'REDLCH':'ReducedLunch', 
                                        'DIRECTCERT':'MealProgramCertified', 'PK':'PreK',
                                        'KG':'Kindergarten', 'G01':'Grade1', 'G02':'Grade2', 
                                        'G03':'Grade3', 'G04':'Grade4', 'G05':'Grade5', 
                                        'G06':'Grade6', 'G07':'Grade7', 'G08':'Grade8', 
                                        'G09':'Grade9','G10':'Grade10', 'G11':'Grade11', 
                                        'G12':'Grade12','G13':'Grade13', 'UG':'Ungraded', 
                                        'AE':'AdultEd', 'TOTMENROL':'TotMaleEnrollment', 
                                        'TOTFENROL':'TotFemaleEnrollment','TOTAL':'TotalEnrollment', 
                                        'MEMBER':'Member', 'FTE':'StaffFTE', 'STUTERATIO':'StudentTeacherRatio', 
                                        'AMALM':'AIANMale','AMALF':'AIANFem', 'AM':'AIANTotal', 
                                        'ASALM':'AsianMale', 'ASALF':'AsianFemale', 'AS':'AsianTotal', 
                                        'BLALM':'BlackMale','BLALF':'BlackFemale', 'BL':'BlackTotal', 
                                        'HPALM':'HPIMale', 'HPALF':'HPIFemale', 'HP':'HPITotal', 
                                        'HIALM':'HispanicMale','HIALF':'HispanicFemale', 'HI':'HispanicTotal', 
                                        'TRALM':'TRMale', 'TRALF':'TRFemale', 'TR':'TRTotal', 
                                        'WHALM':'WhiteMale','WHALF':'WhiteFemale', 'WH':'WhiteTotal', 
                                        'LATCOD':'Latitude','LONCOD':'Longitude'})

ps23Cols = psChar_23.columns
psChar_23.head()
# Out:
#            X        Y  ObjectID       NCESID SurveyYear StateABR   LEAID  \
# 0 -86.206200  34.2602         1  10000500870  2022-2023       AL  100005
# 1 -86.204900  34.2622         2  10000500871  2022-2023       AL  100005
# 2 -86.220100  34.2733         3  10000500879  2022-2023       AL  100005
# 3 -86.221806  34.2527         4  10000500889  2022-2023       AL  100005
# 4 -86.193300  34.2898         5  10000501616  2022-2023       AL  100005
#
#   ST_LEAID           LEAname                         SchoolName  \
# 0   AL-101  Albertville City          Albertville Middle School
# 1   AL-101  Albertville City            Albertville High School
# 2   AL-101  Albertville City    Albertville Intermediate School
# 3   AL-101  Albertville City      Albertville Elementary School
# 4   AL-101  Albertville City  Albertville Kindergarten and PreK
#
#                Street1 Street2         City State    Zip  Zip4          Phone  \
# 0    600 E Alabama Ave     NaN  Albertville    AL  35950        (256)878-2341
# 1     402 E McCord Ave     NaN  Albertville    AL  35950  2322  (256)894-5000
# 2   901 W McKinney Ave     NaN  Albertville    AL  35950  1300  (256)878-7698
# 3   145 West End Drive     NaN  Albertville    AL  35950        (256)894-4822
# 4  257 Country Club Rd     NaN  Albertville    AL  35951  3927  (256)878-7922
#
#   Charter      Virtual LowestGrade HighestGrade SchoolLevel  Status  \
# 0      No  Not Virtual          07           08      Middle       1
# 1      No  Not Virtual          09           12        High       1
# 2      No  Not Virtual          05           06      Middle       1
# 3      No  Not Virtual          03           04  Elementary       1
# 4      No  Not Virtual          PK           KG  Elementary       1
#
#        SchoolType             Status_Text            Locale           County  \
# 0  Regular School  Currently operational   32-Town: Distant  Marshall County
# 1  Regular School  Currently operational   32-Town: Distant  Marshall County
# 2  Regular School  Currently operational   32-Town: Distant  Marshall County
# 3  Regular School  Currently operational   32-Town: Distant  Marshall County
# 4  Regular School  Currently operational   32-Town: Distant  Marshall County
#
#    TotalFreeLunch  FreeLunch  ReducedLunch  MealProgramCertified   PreK  \
# 0             697        654            43                   587    NaN
# 1            1254       1178            76                  1059    NaN
# 2             718        665            53                   570    NaN
# 3             723        680            43                   583    NaN
# 4             392        367            25                   240  133.0
#
#    Kindergarten  Grade1  Grade2  Grade3  Grade4  Grade5  Grade6  Grade7  \
# 0           NaN     NaN     NaN     NaN     NaN     NaN     NaN   440.0
# 1           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN   412.0   462.0     NaN
# 3           NaN     NaN     NaN   430.0   444.0     NaN     NaN     NaN
# 4         473.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Grade8  Grade9  Grade10  Grade11  Grade12  Grade13  Ungraded  AdultEd  \
# 0   450.0     NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 1     NaN   493.0    442.0    390.0    387.0      NaN       NaN      NaN
# 2     NaN     NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 3     NaN     NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 4     NaN     NaN      NaN      NaN      NaN      NaN       NaN      NaN
#
#    TotMaleEnrollment  TotFemaleEnrollment  TotalEnrollment  Member   StaffFTE  \
# 0              459.0                431.0            890.0   890.0  45.000000
# 1              868.0                844.0           1712.0  1712.0  85.199997
# 2              451.0                423.0            874.0   874.0  43.000000
# 3              463.0                411.0            874.0   874.0  43.000000
# 4              304.0                302.0            606.0   606.0  26.000000
#
#    StudentTeacherRatio  AIANMale  AIANFem  AIANTotal  AsianMale  AsianFemale  \
# 0                19.78       4.0      1.0        5.0        4.0          2.0
# 1                20.09       0.0      2.0        2.0        4.0          5.0
# 2                20.33       1.0      4.0        5.0        4.0          0.0
# 3                20.33       0.0      4.0        4.0        1.0          3.0
# 4                23.31       1.0      3.0        4.0        2.0          0.0
#
#    AsianTotal  BlackMale  BlackFemale  BlackTotal  HPIMale  HPIFemale  \
# 0         6.0       15.0         14.0        29.0      0.0        1.0
# 1         9.0       23.0         34.0        57.0      0.0        0.0
# 2         4.0       22.0         28.0        50.0      0.0        0.0
# 3         4.0       22.0         16.0        38.0      0.0        0.0
# 4         2.0       26.0         23.0        49.0      0.0        0.0
#
#    HPITotal  HispanicMale  HispanicFemale  HispanicTotal  TRMale  TRFemale  \
# 0       1.0         251.0           251.0          502.0    17.0      15.0
# 1       0.0         490.0           468.0          958.0    26.0      19.0
# 2       0.0         263.0           241.0          504.0     7.0       6.0
# 3       0.0         261.0           236.0          497.0    11.0      16.0
# 4       0.0         167.0           152.0          319.0     4.0       4.0
#
#    TRTotal  WhiteMale  WhiteFemale  WhiteTotal  Latitude  Longitude
# 0     32.0      168.0        147.0       315.0   34.2602 -86.206200
# 1     45.0      325.0        316.0       641.0   34.2622 -86.204900
# 2     13.0      154.0        144.0       298.0   34.2733 -86.220100
# 3     27.0      168.0        136.0       304.0   34.2527 -86.221806
# 4      8.0      104.0        120.0       224.0   34.2898 -86.193300

# %%
psChar_23.isnull().sum()
# Out:
# X                            0
# Y                            0
# ObjectID                     0
# NCESID                       0
# SurveyYear                   0
# StateABR                     0
# LEAID                        0
# ST_LEAID                     0
# LEAname                      0
# SchoolName                   0
# Street1                      1
# Street2                 100818
# City                         0
# State                        0
# Zip                          0
# Zip4                         0
# Phone                        0
# Charter                      0
# Virtual                      0
# LowestGrade                  0
# HighestGrade                 0
# SchoolLevel                  0
# Status                       0
# SchoolType                   0
# Status_Text                  0
# Locale                       0
# County                       0
# TotalFreeLunch               0
# FreeLunch                    0
# ReducedLunch                 0
# MealProgramCertified         0
# PreK                     68998
# Kindergarten             47329
# Grade1                   46978
# Grade2                   46921
# Grade3                   46931
# Grade4                   47132
# Grade5                   48376
# Grade6                   63367
# Grade7                   68166
# Grade8                   67898
# Grade9                   73289
# Grade10                  73501
# Grade11                  73502
# Grade12                  73574
# Grade13                 101257
# Ungraded                 93501
# AdultEd                 101207
# TotMaleEnrollment         2480
# TotFemaleEnrollment       2480
# TotalEnrollment           1671
# Member                    1671
# StaffFTE                  3853
# StudentTeacherRatio       1814
# AIANMale                  2581
# AIANFem                   2579
# AIANTotal                 2533
# AsianMale                 2492
# AsianFemale               2490
# AsianTotal                2484
# BlackMale                 2494
# BlackFemale               2497
# BlackTotal                2487
# HPIMale                   2608
# HPIFemale                 2607
# HPITotal                  2561
# HispanicMale              2481
# HispanicFemale            2480
# HispanicTotal             2480
# TRMale                    2487
# TRFemale                  2485
# TRTotal                   2484
# WhiteMale                 2481
# WhiteFemale               2481
# WhiteTotal                2480
# Latitude                     0
# Longitude                    0
# dtype: int64

# %%
def missing(DataFrame):
    print('Percentage of missing values in the dataset:\n',
          round((DataFrame.isnull().sum() *100/len(DataFrame)), 2).sort_values(ascending=False))

missing(psChar_23)
# Out:
# Percentage of missing values in the dataset:
#  Grade13                 99.87
# AdultEd                 99.82
# Street2                 99.44
# Ungraded                92.22
# Grade12                 72.57
# Grade10                 72.49
# Grade11                 72.49
# Grade9                  72.28
# PreK                    68.05
# Grade7                  67.23
# Grade8                  66.97
# Grade6                  62.50
# Grade5                  47.71
# Kindergarten            46.68
# Grade4                  46.49
# Grade1                  46.33
# Grade3                  46.29
# Grade2                  46.28
# StaffFTE                 3.80
# HPIFemale                2.57
# HPIMale                  2.57
# AIANMale                 2.55
# AIANFem                  2.54
# HPITotal                 2.53
# AIANTotal                2.50
# AsianMale                2.46
# BlackMale                2.46
# AsianFemale              2.46
# BlackFemale              2.46
# WhiteFemale              2.45
# WhiteTotal               2.45
# TRTotal                  2.45
# AsianTotal               2.45
# BlackTotal               2.45
# HispanicMale             2.45
# HispanicFemale           2.45
# HispanicTotal            2.45
# WhiteMale                2.45
# TotFemaleEnrollment      2.45
# TRFemale                 2.45
# TRMale                   2.45
# TotMaleEnrollment        2.45
# StudentTeacherRatio      1.79
# TotalEnrollment          1.65
# Member                   1.65
# City                     0.00
# Street1                  0.00
# SchoolName               0.00
# LEAname                  0.00
# LEAID                    0.00
# ST_LEAID                 0.00
# StateABR                 0.00
# SurveyYear               0.00
# X                        0.00
# NCESID                   0.00
# ObjectID                 0.00
# Y                        0.00
# ReducedLunch             0.00
# MealProgramCertified     0.00
# TotalFreeLunch           0.00
# FreeLunch                0.00
# Zip                      0.00
# State                    0.00
# Zip4                     0.00
# Phone                    0.00
# Charter                  0.00
# Virtual                  0.00
# LowestGrade              0.00
# HighestGrade             0.00
# SchoolLevel              0.00
# Status                   0.00
# SchoolType               0.00
# Status_Text              0.00
# Locale                   0.00
# County                   0.00
# Latitude                 0.00
# Longitude                0.00
# dtype: float64

# %% [markdown]
# ### Observations

# %% [markdown]
# A total of eighteen columns have missing value percentages above forty-five percent. For the 'Grade' columns, this could be explained because this dataset includes schools at various education levels, meaning some schools might not offer certain grade levels. Furthermore, there are many missing values specifically for the columns regarding free/reduced lunch and the student to teacher ratio. As indicated in the description of this dataset online, these missing values are represented by a number of indicators: -1 indicates that data is missing, -2 or N indicates that data is not applicable, and  -9 indicates that data did not meet NCES data quality standards. Given this information, I would drop the AdultEd column, as this research is focused only on youth sports participation. I would also drop columns 'Phone', 'LEAName', 'LEADID', 'ST_LEAID', 'SurveyYear', 'StaffFTE', 'Member', and 'NCESID', as they are not necessary for analysis. I also plan to remove the columns with negative values.

# %%
dropCols = ['AdultEd','Phone','LEAname','LEAID','ST_LEAID','SurveyYear','StaffFTE','Member','NCESID']

psChar_23 = psChar_23.drop(columns=dropCols)
psChar_23 

psChar_23.isnull().sum()
# Out:
# X                            0
# Y                            0
# ObjectID                     0
# StateABR                     0
# SchoolName                   0
# Street1                      1
# Street2                 100818
# City                         0
# State                        0
# Zip                          0
# Zip4                         0
# Charter                      0
# Virtual                      0
# LowestGrade                  0
# HighestGrade                 0
# SchoolLevel                  0
# Status                       0
# SchoolType                   0
# Status_Text                  0
# Locale                       0
# County                       0
# TotalFreeLunch               0
# FreeLunch                    0
# ReducedLunch                 0
# MealProgramCertified         0
# PreK                     68998
# Kindergarten             47329
# Grade1                   46978
# Grade2                   46921
# Grade3                   46931
# Grade4                   47132
# Grade5                   48376
# Grade6                   63367
# Grade7                   68166
# Grade8                   67898
# Grade9                   73289
# Grade10                  73501
# Grade11                  73502
# Grade12                  73574
# Grade13                 101257
# Ungraded                 93501
# TotMaleEnrollment         2480
# TotFemaleEnrollment       2480
# TotalEnrollment           1671
# StudentTeacherRatio       1814
# AIANMale                  2581
# AIANFem                   2579
# AIANTotal                 2533
# AsianMale                 2492
# AsianFemale               2490
# AsianTotal                2484
# BlackMale                 2494
# BlackFemale               2497
# BlackTotal                2487
# HPIMale                   2608
# HPIFemale                 2607
# HPITotal                  2561
# HispanicMale              2481
# HispanicFemale            2480
# HispanicTotal             2480
# TRMale                    2487
# TRFemale                  2485
# TRTotal                   2484
# WhiteMale                 2481
# WhiteFemale               2481
# WhiteTotal                2480
# Latitude                     0
# Longitude                    0
# dtype: int64

# %%
psChar_23["Status_Text"].unique() #check to see if the schools are operational
# Out:
# array(['Currently operational ',
#        'School to be operational within two years', 'New school',
#        'School temporarily closed',
#        'School was operational but not reported last year',
#        'School has changed agency', 'School has reopened'], dtype=object)

# %%
# filter out negative lunch rates (free, reduced, certified) & student teacher ratios
negativeCols = ['ReducedLunch', 'MealProgramCertified','FreeLunch','StudentTeacherRatio']

psChar_23 = psChar_23[(psChar_23[negativeCols] >= 0).all(axis=1)]

# %%
psChar_23.tail(25)
# Out:
#                  X          Y  ObjectID StateABR  \
# 100480  145.707908  15.161161    100481       MP
# 100482  145.720284  15.211259    100483       MP
# 100483  145.712353  15.164396    100484       MP
# 100484  145.145240  14.140873    100485       MP
# 100485  145.713434  15.163681    100486       MP
# 100486  145.758410  15.241177    100487       MP
# 100487  145.720284  15.211259    100488       MP
# 100488  145.626698  14.974497    100489       MP
# 100489  145.699488  15.140691    100490       MP
# 100490  145.772385  15.249947    100491       MP
# 100491  145.241633  14.160670    100492       MP
# 100492  145.782596  15.164620    100493       MP
# 100493  145.739699  15.153241    100494       MP
# 100494  145.733593  15.137171    100495       MP
# 100495  145.694639  15.132314    100496       MP
# 100496  145.784430  15.167690    100497       MP
# 100498  145.751235  15.209434    100499       MP
# 100499  145.624291  14.971901    100500       MP
# 100500  145.624291  14.971901    100501       MP
# 100501  145.708180  15.120901    100502       MP
# 100502  145.705703  15.119060    100503       MP
# 100503  145.707908  15.161161    100504       MP
# 100504  145.781552  15.166494    100505       MP
# 100506  145.702999  15.140840    100507       MP
# 100507  145.781552  15.166494    100508       MP
#
#                                      SchoolName       Street1 Street2    City  \
# 100480                     MARIANAS HIGH SCHOOL        Susupe     NaN  Saipan
# 100482                GARAPAN ELEMENTARY SCHOOL       Garapan     NaN  Saipan
# 100483                         OLEAI HEAD START         Oleai     NaN  Saipan
# 100484  DR. RITA HOCOG INOS JR. SR. HIGH SCHOOL      Sinapalo     NaN    Rota
# 100485                  OLEAI ELEMENTARY SCHOOL         Oleai     NaN  Saipan
# 100486                    TANAPAG MIDDLE SCHOOL       Tanapag     NaN  Saipan
# 100487                            JMR HEADSTART       Garapan     NaN  Saipan
# 100488               TINIAN JR. SR. HIGH SCHOOL      San Jose     NaN  Tinian
# 100489                    HOPWOOD MIDDLE SCHOOL   Chalan Piao     NaN  Saipan
# 100490    GREGORIO T. CAMACHO ELEMENTARY SCHOOL     San Roque     NaN  Saipan
# 100491                          ROTA HEAD START      Sinapalo     NaN    Rota
# 100492           CHACHA OCEANVIEW MIDDLE SCHOOL        Kagman     NaN  Saipan
# 100493            SAN VICENTE ELEMENTARY SCHOOL   San Vicente     NaN  Saipan
# 100494                     DANDAN MIDDLE SCHOOL        Dandan     NaN  Saipan
# 100495                   SAN ANTONIO HEAD START   San Antonio     NaN  Saipan
# 100496                       KAGMAN HIGH SCHOOL        Kagman     NaN  Saipan
# 100498              EARLY INTERVENTION SERVICES       Garapan     NaN  Saipan
# 100499                        TINIAN HEAD START      San Jose     NaN  Tinian
# 100500                 TINIAN ELEMENTARY SCHOOL      San Jose     NaN  Tinian
# 100501              SAIPAN SOUTHERN HIGH SCHOOL   Koblerville     NaN  Saipan
# 100502            KOBLERVILLE ELEMENTARY SCHOOL   Koblerville     NaN  Saipan
# 100503                            DA'OK ACADEMY        Susupe     NaN  Saipan
# 100504                 KAGMAN ELEMENTARY SCHOOL        Kagman     NaN  Saipan
# 100506            CHALAN KANOA EARLY HEAD START  Chalan Kanoa     NaN  Saipan
# 100507                        KAGMAN HEAD START        Kagman     NaN  Saipan
#
#        State    Zip  Zip4 Charter      Virtual LowestGrade HighestGrade  \
# 100480    MP  96950             N  Not Virtual          09           12
# 100482    MP  96950             N  Not Virtual          KG           05
# 100483    MP  96950             N  Not Virtual          PK           PK
# 100484    MP  96951             N  Not Virtual          07           12
# 100485    MP  96950             N  Not Virtual          KG           05
# 100486    MP  96950             N  Not Virtual          06           08
# 100487    MP  96950             N  Not Virtual          PK           PK
# 100488    MP  96952             N  Not Virtual          07           12
# 100489    MP  96950             N  Not Virtual          06           08
# 100490    MP  96950             N  Not Virtual          KG           05
# 100491    MP  96951             N  Not Virtual          PK           PK
# 100492    MP  96950             N  Not Virtual          06           08
# 100493    MP  96950             N  Not Virtual          KG           05
# 100494    MP  96950             N  Not Virtual          06           08
# 100495    MP  96950             N  Not Virtual          PK           PK
# 100496    MP  96950             N  Not Virtual          09           12
# 100498    MP  96950             N  Not Virtual          UG           UG
# 100499    MP  96952             N  Not Virtual          PK           PK
# 100500    MP  96952             N  Not Virtual          KG           06
# 100501    MP  96950             N  Not Virtual          09           12
# 100502    MP  96950             N  Not Virtual          KG           05
# 100503    MP  96950             N  Not Virtual          09           12
# 100504    MP  96950             N  Not Virtual          KG           05
# 100506    MP  96950             N  Not Virtual          PK           PK
# 100507    MP  96950             N  Not Virtual          PK           PK
#
#             SchoolLevel  Status      SchoolType             Status_Text  \
# 100480             High       1  Regular School  Currently operational
# 100482       Elementary       1  Regular School  Currently operational
# 100483  Prekindergarten       1  Regular School  Currently operational
# 100484             High       1  Regular School  Currently operational
# 100485       Elementary       1  Regular School  Currently operational
# 100486           Middle       1  Regular School  Currently operational
# 100487  Prekindergarten       1  Regular School  Currently operational
# 100488             High       1  Regular School  Currently operational
# 100489           Middle       1  Regular School  Currently operational
# 100490       Elementary       1  Regular School  Currently operational
# 100491  Prekindergarten       1  Regular School  Currently operational
# 100492           Middle       1  Regular School  Currently operational
# 100493       Elementary       1  Regular School  Currently operational
# 100494           Middle       1  Regular School  Currently operational
# 100495  Prekindergarten       1  Regular School  Currently operational
# 100496             High       1  Regular School  Currently operational
# 100498         Ungraded       1  Regular School  Currently operational
# 100499  Prekindergarten       1  Regular School  Currently operational
# 100500       Elementary       1  Regular School  Currently operational
# 100501             High       1  Regular School  Currently operational
# 100502       Elementary       1  Regular School  Currently operational
# 100503             High       1  Regular School  Currently operational
# 100504       Elementary       1  Regular School  Currently operational
# 100506  Prekindergarten       1  Regular School  Currently operational
# 100507  Prekindergarten       1  Regular School  Currently operational
#
#                   Locale               County  TotalFreeLunch  FreeLunch  \
# 100480   33-Town: Remote  Saipan Municipality            1532       1532
# 100482   33-Town: Remote  Saipan Municipality             494        494
# 100483   33-Town: Remote  Saipan Municipality              37         37
# 100484  43-Rural: Remote    Rota Municipality             223        223
# 100485   33-Town: Remote  Saipan Municipality             361        361
# 100486   33-Town: Remote  Saipan Municipality             311        311
# 100487   33-Town: Remote  Saipan Municipality              57         57
# 100488   33-Town: Remote  Tinian Municipality             233        233
# 100489   33-Town: Remote  Saipan Municipality             627        627
# 100490   33-Town: Remote  Saipan Municipality             300        300
# 100491  43-Rural: Remote    Rota Municipality              34         34
# 100492  41-Rural: Fringe  Saipan Municipality             251        251
# 100493   33-Town: Remote  Saipan Municipality             505        505
# 100494   33-Town: Remote  Saipan Municipality             402        402
# 100495   33-Town: Remote  Saipan Municipality              32         32
# 100496   33-Town: Remote  Saipan Municipality             512        512
# 100498   33-Town: Remote  Saipan Municipality              76         76
# 100499   33-Town: Remote  Tinian Municipality              28         28
# 100500   33-Town: Remote  Tinian Municipality             222        222
# 100501   33-Town: Remote  Saipan Municipality             691        691
# 100502   33-Town: Remote  Saipan Municipality             508        508
# 100503   33-Town: Remote  Saipan Municipality              63         63
# 100504  41-Rural: Fringe  Saipan Municipality             454        454
# 100506   33-Town: Remote  Saipan Municipality              23         23
# 100507  41-Rural: Fringe  Saipan Municipality              33         33
#
#         ReducedLunch  MealProgramCertified  PreK  Kindergarten  Grade1  \
# 100480             0                     3   NaN           NaN     NaN
# 100482             0                     3   NaN          71.0    93.0
# 100483             0                     3  37.0           NaN     NaN
# 100484             0                     3   NaN           NaN     NaN
# 100493      NaN      NaN      NaN      NaN       NaN              283.0
# 100494      NaN      NaN      NaN      NaN       NaN              200.0
# 100495      NaN      NaN      NaN      NaN       NaN               14.0
# 100496    120.0    104.0     92.0      NaN       NaN              265.0
# 100498      NaN      NaN      NaN      NaN      76.0               55.0
# 100499      NaN      NaN      NaN      NaN       NaN               13.0
# 100500      NaN      NaN      NaN      NaN       NaN              120.0
# 100501    204.0    124.0     91.0      NaN       NaN              373.0
# 100502      NaN      NaN      NaN      NaN       NaN              252.0
# 100503     22.0     20.0      5.0      NaN       NaN               44.0
# 100504      NaN      NaN      NaN      NaN       NaN              250.0
# 100506      NaN      NaN      NaN      NaN       NaN               14.0
# 100507      NaN      NaN      NaN      NaN       NaN               18.0
#
#         TotFemaleEnrollment  TotalEnrollment  StudentTeacherRatio  AIANMale  \
# 100480                758.0           1530.0                23.54       0.0
# 100482                238.0            492.0                16.40       0.0
# 100483                 17.0             37.0                33.64       0.0
# 100484                100.0            223.0                14.87       0.0
# 100485                182.0            356.0                12.28       1.0
# 100486                143.0            311.0                19.44       0.0
# 100487                 22.0             57.0                51.82       0.0
# 100488                107.0            233.0                15.53       0.0
# 100489                309.0            633.0                14.39       0.0
# 100490                141.0            300.0                15.00       0.0
# 100491                 17.0             34.0                30.91       0.0
# 100492                126.0            251.0                15.69       0.0
# 100493                222.0            505.0                14.85       0.0
# 100494                202.0            402.0                18.27       0.0
# 100495                 18.0             32.0                29.09       0.0
# 100496                247.0            512.0                21.33       0.0
# 100498                 21.0             76.0                25.33       0.0
# 100499                 15.0             28.0                25.45       0.0
# 100500                102.0            222.0                14.80       0.0
# 100501                322.0            695.0                21.06       0.0
# 100502                256.0            508.0                16.93       0.0
# 100503                 19.0             63.0                12.60       0.0
# 100504                204.0            454.0                16.21       0.0
# 100506                  9.0             23.0                20.91       0.0
# 100507                 15.0             33.0                30.00       0.0
#
#         AIANFem  AIANTotal  AsianMale  AsianFemale  AsianTotal  BlackMale  \
# 100480      0.0        0.0      419.0        405.0       824.0        3.0
# 100482      0.0        0.0      129.0        112.0       241.0        0.0
# 100483      0.0        0.0       13.0         13.0        26.0        0.0
# 100484      0.0        0.0       32.0         31.0        63.0        0.0
# 100485      0.0        1.0       68.0         55.0       123.0        0.0
# 100486      0.0        0.0       50.0         30.0        80.0        0.0
# 100487      0.0        0.0       20.0         15.0        35.0        0.0
# 100488      0.0        0.0       51.0         39.0        90.0        0.0
# 100489      0.0        0.0      176.0        180.0       356.0        0.0
# 100490      0.0        0.0       18.0         16.0        34.0        0.0
# 100491      0.0        0.0        3.0          2.0         5.0        0.0
# 100492      0.0        0.0        6.0          9.0        15.0        0.0
# 100493      0.0        0.0       35.0         34.0        69.0        0.0
# 100494      0.0        0.0       62.0         55.0       117.0        0.0
# 100495      0.0        0.0        8.0         11.0        19.0        0.0
# 100496      0.0        0.0       20.0         23.0        43.0        2.0
# 100498      0.0        0.0       17.0          3.0        20.0        0.0
# 100499      0.0        0.0        3.0          6.0         9.0        0.0
# 10           12        High       1  Regular School  Currently operational
# 11           05  Elementary       1  Regular School  Currently operational
# 12           12        High       1  Regular School  Currently operational
# 13           02  Elementary       1  Regular School  Currently operational
# 16           02  Elementary       1  Regular School  Currently operational
# 17           12        High       1  Regular School  Currently operational
# 18           04  Elementary       1  Regular School  Currently operational
# 19           08      Middle       1  Regular School  Currently operational
# 20           05  Elementary       1  Regular School  Currently operational
# 21           05  Elementary       1  Regular School  Currently operational
# 22           05  Elementary       1  Regular School  Currently operational
# 23           12        High       1  Regular School  Currently operational
# 24           08      Middle       1  Regular School  Currently operational
# 25           02  Elementary       1  Regular School  Currently operational
# 26           08      Middle       1  Regular School  Currently operational
# 27           12        High       1  Regular School  Currently operational
#
#                Locale            County  TotalFreeLunch  FreeLunch  \
# 0    32-Town: Distant   Marshall County             697        654
# 1    32-Town: Distant   Marshall County            1254       1178
# 2    32-Town: Distant   Marshall County             718        665
# 3    32-Town: Distant   Marshall County             723        680
# 4    32-Town: Distant   Marshall County             392        367
# 5    32-Town: Distant   Marshall County             779        726
# 6   42-Rural: Distant   Marshall County             151        123
# 7   42-Rural: Distant   Marshall County             555        501
# 9   42-Rural: Distant   Marshall County             245        223
# 10  42-Rural: Distant   Marshall County             334        320
# 11   41-Rural: Fringe   Marshall County             109         99
# 12  42-Rural: Distant   Marshall County             132        115
# 13   41-Rural: Fringe   Marshall County             134        116
# 16  42-Rural: Distant   Marshall County             300        283
# 17   41-Rural: Fringe   Marshall County             280        251
# 18  42-Rural: Distant   Marshall County             254        219
# 19  42-Rural: Distant   Marshall County             263        257
# 20  42-Rural: Distant   Marshall County             590        546
# 21     13-City: Small  Jefferson County             285        243
# 22     13-City: Small     Shelby County              65         58
# 23     13-City: Small  Jefferson County             919        788
# 24     13-City: Small     Shelby County             380        325
# 25     13-City: Small  Jefferson County             108         98
# 26   41-Rural: Fringe     Shelby County             251        216
# 27     13-City: Small     Shelby County             417        360
#
#     ReducedLunch  MealProgramCertified   PreK  Kindergarten  Grade1  Grade2  \
# 0             43                   587    NaN           NaN     NaN     NaN
# 1             76                  1059    NaN           NaN     NaN     NaN
# 2             53                   570    NaN           NaN     NaN     NaN
# 3             43                   583    NaN           NaN     NaN     NaN
# 4             25                   240  133.0         473.0     NaN     NaN
# 5             53                   617    0.0           NaN   427.0   517.0
# 6             28                   194    NaN           NaN     NaN     NaN
# 7             54                   491    NaN           NaN     NaN     NaN
# 9             22                   316    0.0           NaN     NaN     NaN
# 10            14                   438    NaN           NaN     NaN     NaN
# 11            10                   136   38.0           NaN     NaN     NaN
# 12            17                   185    NaN           NaN     NaN     NaN
# 13            18                   175    0.0          73.0    83.0    71.0
# 16            17                   329   87.0         166.0   185.0   158.0
# 17            29                   382    NaN           NaN     NaN     NaN
# 18            35                   293   68.0         106.0   123.0   104.0
# 19             6                   361    NaN           NaN     NaN     NaN
# 20            44                   480   41.0         102.0   132.0   120.0
# 21            42                   237  106.0         120.0   125.0   107.0
# 22             7                    62   23.0          59.0    56.0    63.0
# 23           131                   764    NaN           NaN     NaN     NaN
# 24            55                   318    NaN           NaN     NaN     NaN
# 25            10                    94   48.0         179.0   178.0   163.0
# 26            35                   219    NaN           NaN     NaN     NaN
# 27            57                   355    NaN           NaN     NaN     NaN
#
#     Grade3  Grade4  Grade5  Grade6  Grade7  Grade8  Grade9
# 11 -86.442100
# 12 -86.254153
# 13 -86.422446
# 16 -86.322507
# 17 -86.421900
# 18 -86.254153
# 19 -86.320895
# 20 -86.141422
# 21 -86.844700
# 22 -86.658500
# 23 -86.837700
# 24 -86.732200
# 25 -86.878400
# 26 -86.854796
# 27 -86.728800

# %%
psChar_23['Locale'].unique()
# Out:
# array(['32-Town: Distant', '42-Rural: Distant', '41-Rural: Fringe',
#        '13-City: Small', '21-Suburb: Large', '33-Town: Remote',
#        '31-Town: Fringe', '23-Suburb: Small', '12-City: Mid-size',
#        '43-Rural: Remote', '22-Suburb: Mid-size', '11-City: Large'],
#       dtype=object)

# %%
Locale = {'42-Rural: Distant':'Rural',
            '41-Rural: Fringe':'Rural',
            '43-Rural: Remote':'Rural',
            '32-Town: Distant':'Town',
            '33-Town: Remote':'Town',
            '31-Town: Fringe':'Town',
            '13-City: Small':'City',
            '12-City: Mid-size':'City',
            '11-City: Large':'City',
            '21-Suburb: Large':'Suburb',
            '23-Suburb: Small':'Suburb',
            '22-Suburb: Mid-size':'Suburb'}

Locale
# Out:
# {'42-Rural: Distant': 'Rural',
#  '41-Rural: Fringe': 'Rural',
#  '43-Rural: Remote': 'Rural',
#  '32-Town: Distant': 'Town',
#  '33-Town: Remote': 'Town',
#  '31-Town: Fringe': 'Town',
#  '13-City: Small': 'City',
#  '12-City: Mid-size': 'City',
#  '11-City: Large': 'City',
#  '21-Suburb: Large': 'Suburb',
#  '23-Suburb: Small': 'Suburb',
#  '22-Suburb: Mid-size': 'Suburb'}

# %%
psChar_23['Locale'] = psChar_23['Locale'].map(Locale)

psChar_23['Locale'].unique()
# Out:
# array(['Town', 'Rural', 'City', 'Suburb'], dtype=object)

# %%
psChar_23.head()
# Out:
#            X        Y  ObjectID StateABR                         SchoolName  \
# 0 -86.206200  34.2602         1       AL          Albertville Middle School
# 1 -86.204900  34.2622         2       AL            Albertville High School
# 2 -86.220100  34.2733         3       AL    Albertville Intermediate School
# 3 -86.221806  34.2527         4       AL      Albertville Elementary School
# 4 -86.193300  34.2898         5       AL  Albertville Kindergarten and PreK
#
#                Street1 Street2         City State    Zip  Zip4 Charter  \
# 0    600 E Alabama Ave     NaN  Albertville    AL  35950            No
# 1     402 E McCord Ave     NaN  Albertville    AL  35950  2322      No
# 2   901 W McKinney Ave     NaN  Albertville    AL  35950  1300      No
# 3   145 West End Drive     NaN  Albertville    AL  35950            No
# 4  257 Country Club Rd     NaN  Albertville    AL  35951  3927      No
#
#        Virtual LowestGrade HighestGrade SchoolLevel  Status      SchoolType  \
# 0  Not Virtual          07           08      Middle       1  Regular School
# 1  Not Virtual          09           12        High       1  Regular School
# 2  Not Virtual          05           06      Middle       1  Regular School
# 3  Not Virtual          03           04  Elementary       1  Regular School
# 4  Not Virtual          PK           KG  Elementary       1  Regular School
#
#               Status_Text Locale           County  TotalFreeLunch  FreeLunch  \
# 0  Currently operational    Town  Marshall County             697        654
# 1  Currently operational    Town  Marshall County            1254       1178
# 2  Currently operational    Town  Marshall County             718        665
# 3  Currently operational    Town  Marshall County             723        680
# 4  Currently operational    Town  Marshall County             392        367
#
#    ReducedLunch  MealProgramCertified   PreK  Kindergarten  Grade1  Grade2  \
# 0            43                   587    NaN           NaN     NaN     NaN
# 1            76                  1059    NaN           NaN     NaN     NaN
# 2            53                   570    NaN           NaN     NaN     NaN
# 3            43                   583    NaN           NaN     NaN     NaN
# 4            25                   240  133.0         473.0     NaN     NaN
#
#    Grade3  Grade4  Grade5  Grade6  Grade7  Grade8  Grade9  Grade10  Grade11  \
# 0     NaN     NaN     NaN     NaN   440.0   450.0     NaN      NaN      NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN   493.0    442.0    390.0
# 2     NaN     NaN   412.0   462.0     NaN     NaN     NaN      NaN      NaN
# 3   430.0   444.0     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
#
#    Grade12  Grade13  Ungraded  TotMaleEnrollment  TotFemaleEnrollment  \
# 0      NaN      NaN       NaN              459.0                431.0
# 1    387.0      NaN       NaN              868.0                844.0
# 2      NaN      NaN       NaN              451.0                423.0
# 3      NaN      NaN       NaN              463.0                411.0
# 4      NaN      NaN       NaN              304.0                302.0
#
#    TotalEnrollment  StudentTeacherRatio  AIANMale  AIANFem  AIANTotal  \
# 0            890.0                19.78       4.0      1.0        5.0
# 1           1712.0                20.09       0.0      2.0        2.0
# 2            874.0                20.33       1.0      4.0        5.0
# 3            874.0                20.33       0.0      4.0        4.0
# 4            606.0                23.31       1.0      3.0        4.0
#
#    AsianMale  AsianFemale  AsianTotal  BlackMale  BlackFemale  BlackTotal  \
# 0        4.0          2.0         6.0       15.0         14.0        29.0
# 1        4.0          5.0         9.0       23.0         34.0        57.0
# 2        4.0          0.0         4.0       22.0         28.0        50.0
# 3        1.0          3.0         4.0       22.0         16.0        38.0
# 4        2.0          0.0         2.0       26.0         23.0        49.0
#
#    HPIMale  HPIFemale  HPITotal  HispanicMale  HispanicFemale  HispanicTotal  \
# 0      0.0        1.0       1.0         251.0           251.0          502.0
# 1      0.0        0.0       0.0         490.0           468.0          958.0
# 2      0.0        0.0       0.0         263.0           241.0          504.0
# 3      0.0        0.0       0.0         261.0           236.0          497.0
# 4      0.0        0.0       0.0         167.0           152.0          319.0
#
#    TRMale  TRFemale  TRTotal  WhiteMale  WhiteFemale  WhiteTotal  Latitude  \
# 0    17.0      15.0     32.0      168.0        147.0       315.0   34.2602
# 1    26.0      19.0     45.0      325.0        316.0       641.0   34.2622
# 2     7.0       6.0     13.0      154.0        144.0       298.0   34.2733
# 3    11.0      16.0     27.0      168.0        136.0       304.0   34.2527
# 4     4.0       4.0      8.0      104.0        120.0       224.0   34.2898
#
#    Longitude
# 0 -86.206200
# 1 -86.204900
# 2 -86.220100
# 3 -86.221806
# 4 -86.193300

# %%
psChar_23og = psChar_23

# %%
psChar_23.describe()
# Out:
#                   X             Y       ObjectID           Zip        Status  \
# count  39912.000000  39912.000000   39912.000000  39912.000000  39912.000000
# mean    -100.645425     37.341436   36046.387452  64077.592904      1.015760
# std       19.524876      6.028829   28990.945756  28479.401078      0.207057
# min     -171.715402     14.140873       1.000000   3901.000000      1.000000
# 25%     -118.273092     33.770583   11760.750000  34743.750000      1.000000
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      1.000000      1.000000      1.000000
# 50%        3.000000      3.000000      5.000000     10.000000      9.000000
# 75%       13.000000     12.000000     25.000000     50.000000     48.000000
# max     1335.000000   1224.000000   2559.000000   2195.000000   2207.000000
#
#          BlackTotal       HPIMale     HPIFemale      HPITotal  HispanicMale  \
# count  39120.000000  39058.000000  39063.000000  39091.000000  39126.000000
# mean      85.148108      1.716396      1.621995      3.335781     86.968665
# std      158.755783     10.177131      9.541043     19.614712    133.961622
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        3.000000      0.000000      0.000000      0.000000     10.000000
# 50%       19.000000      0.000000      0.000000      0.000000     37.000000
# 75%       98.000000      1.000000      1.000000      2.000000    113.000000
# max     4402.000000    556.000000    440.000000    996.000000   1947.000000
#
#        HispanicFemale  HispanicTotal        TRMale      TRFemale  \
# count    39126.000000   39126.000000  39123.000000  39124.000000
# mean        82.863978     169.832643     15.496894     14.868674
# std        128.581174     261.864440     18.929447     18.456744
# min          0.000000       0.000000      0.000000      0.000000
# 25%          9.000000      20.000000      3.000000      3.000000
# 50%         35.000000      72.000000     10.000000     10.000000
# 75%        107.000000     220.750000     21.000000     21.000000
# max       2118.000000    4065.000000    436.000000    422.000000
#
#             TRTotal     WhiteMale   WhiteFemale    WhiteTotal      Latitude  \
# count  39124.000000  39126.000000  39126.000000  39126.000000  39912.000000
# mean      30.365172    116.305935    108.637888    224.943823     37.341436
# std       36.906856    130.286457    124.978932    254.496069      6.028829
# min        0.000000      0.000000      0.000000      0.000000     14.140873
# 25%        6.000000     21.000000     19.000000     40.000000     33.770583
# 50%       20.000000     81.000000     74.000000    155.000000     37.017900
# 75%       42.000000    165.000000    154.000000    319.000000     39.807874
# max      828.000000   1989.000000   2305.000000   4294.000000     71.300337
#
#           Longitude
# count  39912.000000
# mean    -100.645425
# std       19.524876
# min     -171.715402
# 25%     -118.273092
# 50%      -94.217945
# 75%      -84.559025
# max      145.784430

# %% [markdown]
# ### Observations of Descriptive Statistics

# %% [markdown]
# (Min, Max):
# - TotalFreeLunch (3, 5770); FreeLunch (0, 5563); ReducedLunch (0, 1400); MealProgramCertified (3, 2921)
# - PreK (0, 1013)
# - Kindergarten (0, 873)
# - Grade1 (0, 646)
# - Grade2 (0, 665)
# - Grade3 (0, 691)
# - Grade4 (0, 669)
# - Grade5 (0, 727)
# - Grade6 (0, 923)
# - Grade7 (0, 844)
# - Grade8 (0, 930)
# - Grade9 (0, 6251)
# - Grade10 (0, 2855)
# - Grade11 (0, 1293)
# - Grade12 (0, 1339)
# - Grade13 (0, 0)
# - Ungraded (0, 223)
# - Total Male Enrollment (0, 4352); Total Female Enrollment (0, 4524); Total Enrollment (9, 8876)
# - Student Teacher Ratio (0, 1860)
# - American Indian/Alaskan Native Male (0, 585); American Indian/Alaskan Native Female (0, 513); American Indian/Alaskan Native Total (0, 1098)
# - Asian Male (0, 1335); Asian Female (0, 1224); Asian Total (0, 2559)
# - Black Male (0, 2195); Black Female (0, 2207); Black Total (0, 4402)
# - Native Hawaiian/Pacific Islander(HPI) Male (0, 556); Native Hawaiian/Pacific Islander(HPI) Female (0, 440); Native Hawaiian/Pacific Islander(HPI) Total (0, 996)
# - Hispanic Male (0, 1947); Hispanic Female (0, 2118); Hispanic Total (0, 4065)
# - Two or More Races Male (0, 436); Two or More Races Female (0, 422); Two or More Races Total (0, 828)
# - White Male (0, 1989); White Female (0, 2305); White Total (0, 4294)

# %% [markdown]
# Mean:
# - TotalFreeLunch: 314.66; FreeLunch: 280.87; ReducedLunch: 33.79; MealProgramCertified: 202.52
# - PreK: 33.45 students
# - Kindergarten: 70.58 students
# - Grade1: 69.16 students
# - Grade2: 67.52 students
# - Grade3: 69.63 students
# - Grade4: 68.95 students
# - Grade5: 70.47 students
# - Grade6: 103.58 students
# - Grade7: 128.04 students
# - Grade8: 130.64 students
# - Grade9: 181.99 students
# - Grade10: 176.63 students
# - Grade11: 165.34 students
# - Grade12: 161.39 students
# - Grade13: NaN students
# - Ungraded: 5.56 students
# - Total Male Enrollment: 285.13 students; Total Female Enrollment 269.76: students; Total Enrollment: 555.07 students
# - Student Teacher Ratio: 17.13 students/teacher
# - American Indian/Alaskan Native Male: 3.30 students; American Indian/Alaskan Native Female: 3.18 students; American Indian/Alaskan Native Total: 6.47 students
# - Asian Male: 17.97 students; Asian Female 16.84 students; Asian Total: 34.82 students
# - Black Male: 43.40 students; Black Female: 41.77 students; Black Total: 85.15 students
# - Native Hawaiian/Pacific Islander(HPI) Male: 1.72 students; Native Hawaiian/Pacific Islander(HPI) Female: 1.62 students; Native Hawaiian/Pacific Islander(HPI) Total: 3.4 students
# - Hispanic Male: 86.97 students; Hispanic Female: 82.86 students; Hispanic Total: 169.83 students
# - Two or More Races Male: 15.50 students; Two or More Races Female: 14.87 students; Two or More Races Total: 30.37 students
# - White Male: 116.31 students; White Female: 108.64 students; White Total: 224.94 students

# %% [markdown]
# Quartile Ranges (25%, 75%):
#
# - TotalFreeLunch: (118, 414.25); FreeLunch: (99, 375); ReducedLunch (3, 43); MealProgramCertified: (64, 276)
# - PreK: (10, 43)
# - Kindergarten: (43, 94)
# - Grade1: (42, 91)
# - Grade2: (41, 89)
# - Grade3: (42, 92)
# - Grade4: (41, 91)
# - Grade5: (41, 93)
# - Grade6: (28, 139)
# - Grade7: (23, 209)
# - Grade8: (23, 215)
# - Grade9: (16, 309)
# - Grade10: (19, 296)
# - Grade11: (23, 265)
# - Grade12: (26, 252)
# - Grade13: (NaN, NaN)
# - Ungraded: (0, 8)
# - Total Male Enrollment: (141, 348); Total Female Enrollment: (132, 329); Total Enrollment: (274, 674)
# - Student Teacher Ratio: (13.27, 19.98)
# - American Indian/Alaskan Native Male: (0, 2); American Indian/Alaskan Native Female: (0, 2); American Indian/Alaskan Native Total: (0, 3)
# - Asian Male: (0, 13); Asian Female: (0, 12); Asian Total: (1, 25)
# - Black Male: (1, 48); Black Female: (1, 48); Black Total: (3, 98)
# - Native Hawaiian/Pacific Islander(HPI) Male: (0, 1); Native Hawaiian/Pacific Islander(HPI) Female: (0, 1); Native Hawaiian/Pacific Islander(HPI) Total: (0, 2)
# - Hispanic Male: (10, 113); Hispanic Female: (9, 107); Hispanic Total: (20, 220)
# - Two or More Races Male: (3, 21); Two or More Races Female: (3, 21); Two or More Races Total: (6, 42)
# - White Male: (21, 165); White Female: (19, 154); White Total: (40, 319)

# %% [markdown]
# Standard Deviation:
#
# Higher than mean- Reduced Lunch, Meal Program Certified, PreK, Grade6 - Grade12, Ungraded; AIAN, Asian, Black, HPI, Hispanic, and White demographics.
# Lower- Total Free Lunch, Free Lunch, Kindergarten - Grade5, Total Male Enrollment, Total Female Enrollment, Total Wneollment, Student to Teacher Ratio
#
# The standard deviation of Total Free Lunch, Free Lunch, and Meal Program Certified are all moderately close to the mean, while the difference in Reduced Lunch is a bit larger.
#
# The standard deviation for PreK students is higher than the mean, while the standard deviations for Kindergarten through Grade 5 are all lower. The standard deviations for ungraded students and from Grade 6 and above are higher than the means.
#
# The standard deviations for enrollment rates are moderately lower than the means.
#
# The standard deviation for the student to teacher ratio is a bit lower than the mean.
#
# The standard deviations for all student demographics are higher than the means, though the disparity found in White student demographics is much less significant compared to other races/ethnicities. The greatest disparities are found in the Hispanic and Black Total columns.

# %% [markdown]
# Mean/Median Closeness:
#
# The medians for the free/reduced lunch status of the schools are lower than the means (skewed left).
#
# For the columns covering the elementary school grades and the student/teacher ratio, the mean and median are close. For the other grades, the values are skewed left. They are also close for Grade13 and Ungraded students, and American Indian/Alaskan Native and Native Hawaiian/Pacific Islander demographics, because of the smaller sampling size.
#
# The median for the student-teacher ratio is close to the mean.
#
# The medians for enrollment rates are lower than the means.
#
# The medians for Asian student & students belonging to Two or More Races (TR) demographics are lower than the means.
#
# The medians for Black and Hispanic student demographics are significantly lower than the means.
#
# The medians for White student demographics are lower than the means.

# %%
print(psChar_23["StudentTeacherRatio"].describe())
# Out:
# count    39912.000000
# mean        17.127401
# std         14.542015
# min          0.000000
# 25%         13.270000
# 50%         16.030000
# 75%         19.980000
# max       1860.000000
# Name: StudentTeacherRatio, dtype: float64

# %%
print(psChar_23["StudentTeacherRatio"].describe())
# Out:
# count    39912.000000
# mean        17.127401
# std         14.542015
# min          0.000000
# 25%         13.270000
# 50%         16.030000
# 75%         19.980000
# max       1860.000000
# Name: StudentTeacherRatio, dtype: float64

# %%
psChar_23.columns
# Out:
# Index(['X', 'Y', 'ObjectID', 'StateABR', 'SchoolName', 'Street1', 'Street2',
#        'City', 'State', 'Zip', 'Zip4', 'Charter', 'Virtual', 'LowestGrade',
#        'HighestGrade', 'SchoolLevel', 'Status', 'SchoolType', 'Status_Text',
#        'Locale', 'County', 'TotalFreeLunch', 'FreeLunch', 'ReducedLunch',
#        'MealProgramCertified', 'PreK', 'Kindergarten', 'Grade1', 'Grade2',
#        'Grade3', 'Grade4', 'Grade5', 'Grade6', 'Grade7', 'Grade8', 'Grade9',
#        'Grade10', 'Grade11', 'Grade12', 'Grade13', 'Ungraded',
#        'TotMaleEnrollment', 'TotFemaleEnrollment', 'TotalEnrollment',
#        'StudentTeacherRatio', 'AIANMale', 'AIANFem', 'AIANTotal', 'AsianMale',
#        'AsianFemale', 'AsianTotal', 'BlackMale', 'BlackFemale', 'BlackTotal',
#        'HPIMale', 'HPIFemale', 'HPITotal', 'HispanicMale', 'HispanicFemale',
#        'HispanicTotal', 'TRMale', 'TRFemale', 'TRTotal', 'WhiteMale',
#        'WhiteFemale', 'WhiteTotal', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
#1: scatter plot to visualize correlation between reduced/free lunch vs. percentage of student enrollment by race 
#2: compare student teacher ratio to reduced/free lunch as an indicator of resource disparities

# %%
print(type(psChar_23))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import matplotlib.pyplot as plt
import numpy as np

psChar_23 = psChar_23[psChar_23["TotalFreeLunch"] <= psChar_23["TotalEnrollment"]]
psChar_23["LunchRate"] = (psChar_23["TotalFreeLunch"] / psChar_23["TotalEnrollment"]) * 100

race_colors = {"BlackTotal": "tab:green", "HispanicTotal": "tab:orange", "WhiteTotal": "tab:blue"}
size_values = {"BlackTotal": 45, "HispanicTotal": 45, "WhiteTotal": 45} 
psChar_23["PredominantRace"] = psChar_23[["BlackTotal", "HispanicTotal", "WhiteTotal"]].idxmax(axis=1)

fig, ax = plt.subplots()
for race, color in race_colors.items():
    subset = psChar_23[psChar_23["PredominantRace"] == race]  
    x = subset["LunchRate"]
    y = subset["StudentTeacherRatio"]
    scale = 200.0 * np.random.rand(len(subset))
    ax.scatter(x, y, c=color, s=size_values[race], label=race, alpha=0.3, edgecolors='none')

ax.legend(('Predominately Black School', 'Predominately Latino/Hispanic School', 'Predominately White School'), loc='upper right', shadow=True)
ax.grid(True)
ax.set_xlabel("Lunch Rate (%)")
ax.set_ylabel("Students per Teacher")
ax.set_title("Lunch Rate & Student-Teacher Ratio (by Race)")

ax.set_xlim(0, 100)  # Assuming LunchRate is a percentage
ax.set_ylim(0, 50)   # Adjust based on expected student-teacher ratio values

ax.set_ymargin(0.1)   
ax.set_xmargin(0.1)

plt.show()

# %%
# breakdown of lunch rate/student to teacher ratio -- just hispanic/latino demographic

import matplotlib.pyplot as plt
import numpy as np

psChar_23 = psChar_23[psChar_23["TotalFreeLunch"] <= psChar_23["TotalEnrollment"]]
psChar_23["LunchRate"] = (psChar_23["TotalFreeLunch"] / psChar_23["TotalEnrollment"]) * 100

race_colors = {"BlackTotal": "tab:green", "HispanicTotal": "tab:orange", "WhiteTotal": "tab:blue"}
size_values = {"BlackTotal": 0, "HispanicTotal": 45, "WhiteTotal": 0} 
psChar_23["PredominantRace"] = psChar_23[["BlackTotal", "HispanicTotal", "WhiteTotal"]].idxmax(axis=1)

fig, ax = plt.subplots()
for race, color in race_colors.items():
    subset = psChar_23[psChar_23["PredominantRace"] == race]  
    x = subset["LunchRate"]
    y = subset["StudentTeacherRatio"]
    scale = 200.0 * np.random.rand(len(subset))
    ax.scatter(x, y, c=color, s=size_values[race], label=race, alpha=0.3, edgecolors='none')


ax.grid(True)
ax.set_xlabel("Lunch Rate (%)")
ax.set_ylabel("Students per Teacher")
ax.set_title("Lunch Rate & Student-Teacher Ratio (by Race)")

ax.set_xlim(0, 100)  # Assuming LunchRate is a percentage
ax.set_ylim(0, 50)   # Adjust based on expected student-teacher ratio values

ax.set_ymargin(0.1)   
ax.set_xmargin(0.1)

plt.show()

# %%
# breakdown of lunch rate/student to teacher ratio -- just black demographic

import matplotlib.pyplot as plt
import numpy as np

psChar_23 = psChar_23[psChar_23["TotalFreeLunch"] <= psChar_23["TotalEnrollment"]]
psChar_23["LunchRate"] = (psChar_23["TotalFreeLunch"] / psChar_23["TotalEnrollment"]) * 100

race_colors = {"BlackTotal": "tab:green", "HispanicTotal": "tab:orange", "WhiteTotal": "tab:blue"}
size_values = {"BlackTotal": 45, "HispanicTotal": 0, "WhiteTotal": 0} 
psChar_23["PredominantRace"] = psChar_23[["BlackTotal", "HispanicTotal", "WhiteTotal"]].idxmax(axis=1)

fig, ax = plt.subplots()
for race, color in race_colors.items():
    subset = psChar_23[psChar_23["PredominantRace"] == race]  
    x = subset["LunchRate"]
    y = subset["StudentTeacherRatio"]
    scale = 200.0 * np.random.rand(len(subset))
    ax.scatter(x, y, c=color, s=size_values[race], label=race, alpha=0.3, edgecolors='none')


ax.grid(True)
ax.set_xlabel("Lunch Rate (%)")
ax.set_ylabel("Students per Teacher")
ax.set_title("Lunch Rate & Student-Teacher Ratio (by Race)")

ax.set_xlim(0, 100)  # Assuming LunchRate is a percentage
ax.set_ylim(0, 50)   # Adjust based on expected student-teacher ratio values

ax.set_ymargin(0.1)   
ax.set_xmargin(0.1)

plt.show()

# %%
# breakdown of lunch rate/student to teacher ratio -- just white demographic

import matplotlib.pyplot as plt
import numpy as np

psChar_23 = psChar_23[psChar_23["TotalFreeLunch"] <= psChar_23["TotalEnrollment"]]
psChar_23["LunchRate"] = (psChar_23["TotalFreeLunch"] / psChar_23["TotalEnrollment"]) * 100

race_colors = {"BlackTotal": "tab:green", "HispanicTotal": "tab:orange", "WhiteTotal": "tab:blue"}
size_values = {"BlackTotal": 0, "HispanicTotal": 0, "WhiteTotal": 45} 
psChar_23["PredominantRace"] = psChar_23[["BlackTotal", "HispanicTotal", "WhiteTotal"]].idxmax(axis=1)

fig, ax = plt.subplots()
for race, color in race_colors.items():
    subset = psChar_23[psChar_23["PredominantRace"] == race]  
    x = subset["LunchRate"]
    y = subset["StudentTeacherRatio"]
    scale = 200.0 * np.random.rand(len(subset))
    ax.scatter(x, y, c=color, s=size_values[race], label=race, alpha=0.3, edgecolors='none')


ax.grid(True)
ax.set_xlabel("Lunch Rate (%)")
ax.set_ylabel("Students per Teacher")
ax.set_title("Lunch Rate & Student-Teacher Ratio (by Race)")

ax.set_xlim(0, 100)  # Assuming LunchRate is a percentage
ax.set_ylim(0, 50)   # Adjust based on expected student-teacher ratio values

ax.set_ymargin(0.1)   
ax.set_xmargin(0.1)

plt.show()
